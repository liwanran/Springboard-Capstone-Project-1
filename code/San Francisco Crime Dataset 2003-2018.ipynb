# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %% [markdown]
# # 1. This dataset reflects the crime incidents that occurred in San Francisco from 2003 to May 2018. Source: https://data.sfgov.org/Public-Safety/Police-Department-Incident-Reports-Historical-2003/tmnf-yvry

# %%
# import the dataset
p1 = pd.read_csv('datasets/major/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv')
p1.head()
# Out:
#    IncidntNum        Category                      Descript DayOfWeek  \
# 0   180362289   VEHICLE THEFT             STOLEN MOTORCYCLE   Tuesday
# 1   180360948    NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED   Tuesday
# 2   180360879  OTHER OFFENSES              PAROLE VIOLATION   Tuesday
# 3   180360879  OTHER OFFENSES      TRAFFIC VIOLATION ARREST   Tuesday
# 4   180360879  OTHER OFFENSES             TRAFFIC VIOLATION   Tuesday
#
#          Date   Time PdDistrict      Resolution  \
# 0  05/15/2018  10:30   SOUTHERN            NONE
# 1  05/15/2018  04:14   SOUTHERN            NONE
# 2  05/15/2018  02:01    MISSION  ARREST, BOOKED
# 3  05/15/2018  02:01    MISSION  ARREST, BOOKED
# 4  05/15/2018  02:01    MISSION  ARREST, BOOKED
#
#                          Address           X  ...  \
# 0         700 Block of TEHAMA ST -122.411912  ...
# 1  MARKET ST / SOUTH VAN NESS AV -122.419258  ...
# 2              CAPP ST / 21ST ST -122.417813  ...
# ...

# %%
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215024 entries, 0 to 2215023
# Data columns (total 33 columns):
# IncidntNum                      int64
# Category                        object
# Descript                        object
# DayOfWeek                       object
# Date                            object
# Time                            object
# PdDistrict                      object
# Resolution                      object
# Address                         object
# X                               float64
# Y                               float64
# Location                        object
# PdId                            int64
# SF Find Neighborhoods           float64
# Current Police Districts        float64
# Current Supervisor Districts    float64
# Analysis Neighborhoods          float64
# :@computed_region_yftq_j783     float64
# :@computed_region_p5aj_wyqh     float64
# :@computed_region_rxqg_mtj9     float64
# :@computed_region_bh8s_q3mv     float64
# ...

# %%
# see column names
p1.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location', 'PdId',
#        'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        ':@computed_region_yftq_j783', ':@computed_region_p5aj_wyqh',
#        ':@computed_region_rxqg_mtj9', ':@computed_region_bh8s_q3mv',
#        ':@computed_region_fyvs_ahh9', ':@computed_region_9dfj_4gjx',
#        ':@computed_region_n4xg_c4py', ':@computed_region_4isq_27mq',
#        ':@computed_region_fcz8_est8', ':@computed_region_pigm_ib2e',
#        ':@computed_region_9jxd_iqea', ':@computed_region_6pnf_4xz7',
#        ':@computed_region_6ezc_tdp2', ':@computed_region_h4ep_8xdi',
#        ':@computed_region_nqbw_i6c3', ':@computed_region_2dwj_jsy4'],
#       dtype='object')

# %%
# see number of rows and columns
p1.shape
# Out:
# (2215024, 33)

# %%
p1.isnull().sum()
# Out:
# IncidntNum                            0
# Category                              0
# Descript                              0
# DayOfWeek                             0
# Date                                  0
# Time                                  0
# PdDistrict                            1
# Resolution                            0
# Address                               0
# X                                     0
# Y                                     0
# Location                              0
# PdId                                  0
# SF Find Neighborhoods              6077
# Current Police Districts           1112
# Current Supervisor Districts        661
# Analysis Neighborhoods             1057
# :@computed_region_yftq_j783        5580
# :@computed_region_p5aj_wyqh        1523
# :@computed_region_rxqg_mtj9         661
# :@computed_region_bh8s_q3mv         495
# :@computed_region_fyvs_ahh9        1057
# :@computed_region_9dfj_4gjx     1666617
# ...

# %% [markdown]
# ## As the most fields in ":computed_region_" columns are null values, we remove these columns below by dropping them.

# %%
# remove irrelevant columns
p1.drop(['PdId',
        ':@computed_region_yftq_j783', 
         ':@computed_region_p5aj_wyqh',
         ':@computed_region_rxqg_mtj9',
        ':@computed_region_bh8s_q3mv', 
        ':@computed_region_fyvs_ahh9',
        ':@computed_region_9dfj_4gjx',
        ':@computed_region_n4xg_c4py',
        ':@computed_region_4isq_27mq',
        ':@computed_region_fcz8_est8',
        ':@computed_region_pigm_ib2e',
        ':@computed_region_9jxd_iqea',
        ':@computed_region_6pnf_4xz7',
        ':@computed_region_6ezc_tdp2',
        ':@computed_region_h4ep_8xdi',
        ':@computed_region_nqbw_i6c3',
        ':@computed_region_2dwj_jsy4'], axis=1, inplace=True)
p1.head()
# Out:
#    IncidntNum        Category                      Descript DayOfWeek  \
# 0   180362289   VEHICLE THEFT             STOLEN MOTORCYCLE   Tuesday
# 1   180360948    NON-CRIMINAL  AIDED CASE, MENTAL DISTURBED   Tuesday
# 2   180360879  OTHER OFFENSES              PAROLE VIOLATION   Tuesday
# 3   180360879  OTHER OFFENSES      TRAFFIC VIOLATION ARREST   Tuesday
# 4   180360879  OTHER OFFENSES             TRAFFIC VIOLATION   Tuesday
#
#          Date   Time PdDistrict      Resolution  \
# 0  05/15/2018  10:30   SOUTHERN            NONE
# 1  05/15/2018  04:14   SOUTHERN            NONE
# 2  05/15/2018  02:01    MISSION  ARREST, BOOKED
# 3  05/15/2018  02:01    MISSION  ARREST, BOOKED
# 4  05/15/2018  02:01    MISSION  ARREST, BOOKED
#
#                          Address           X          Y  \
# 0         700 Block of TEHAMA ST -122.411912  37.775207
# 1  MARKET ST / SOUTH VAN NESS AV -122.419258  37.775146
# 2              CAPP ST / 21ST ST -122.417813  37.757101
# ...

# %%
# convert p1['date'] from string to datetime
p1['Date'] = pd.to_datetime(p1['Date'])
p1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215024 entries, 0 to 2215023
# Data columns (total 16 columns):
# IncidntNum                      int64
# Category                        object
# Descript                        object
# DayOfWeek                       object
# Date                            datetime64[ns]
# Time                            object
# PdDistrict                      object
# Resolution                      object
# Address                         object
# X                               float64
# Y                               float64
# Location                        object
# SF Find Neighborhoods           float64
# Current Police Districts        float64
# Current Supervisor Districts    float64
# Analysis Neighborhoods          float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(8)
# memory usage: 270.4+ MB

# %% [markdown]
# ## Extract crime cases from from 2003 to 2017 from this dataset.

# %%
p2003_2017 = p1[p1['Date'].dt.year < 2018]
p2003_2017.head()
# Out:
#        IncidntNum       Category  \
# 46668   180000417        ASSAULT
# 46669   180000069        ASSAULT
# 46670   180000069       BURGLARY
# 46671   180000069    WEAPON LAWS
# 46672   186005077  LARCENY/THEFT
#
#                                              Descript DayOfWeek       Date  \
# 46668                                         BATTERY    Sunday 2017-12-31
# 46669                 AGGRAVATED ASSAULT WITH A KNIFE    Sunday 2017-12-31
# 46670     BURGLARY OF APARTMENT HOUSE, FORCIBLE ENTRY    Sunday 2017-12-31
# 46671  EXHIBITING DEADLY WEAPON IN A THREATING MANNER    Sunday 2017-12-31
# 46672                         PETTY THEFT OF PROPERTY    Sunday 2017-12-31
#
#         Time  PdDistrict      Resolution                   Address  \
# 46668  23:58    SOUTHERN            NONE    800 Block of BRYANT ST
# 46669  23:56  TENDERLOIN  ARREST, BOOKED     500 Block of JONES ST
# 46670  23:56  TENDERLOIN  ARREST, BOOKED     500 Block of JONES ST
# ...

# %%
p2003_2017.shape
# Out:
# (2168356, 16)

# %% [markdown]
# # 2. This dataset reflects the crime incidents that occurred in San Francisco from 1/1/2018 to 4/18/2019. Source: https://catalog.data.gov/dataset/police-department-incident-reports-2018-to-present

# %%
# import dataset
p2 = pd.read_csv('datasets/major/Police_Department_Incident_Reports__2018_to_Present.csv')
p2.head()
# Out:
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2018/12/02 12:45:00 AM    2018/12/02         00:45           2018
# 1  2018/12/01 08:30:00 PM    2018/12/01         20:30           2018
# 2  2019/03/18 02:01:00 PM    2019/03/18         14:01           2019
# 3  2019/03/20 08:00:00 AM    2019/03/20         08:00           2019
# 4  2019/03/12 01:30:00 PM    2019/03/12         13:30           2019
#
#   Incident Day of Week         Report Datetime       Row ID  Incident ID  \
# 0               Sunday  2018/12/02 01:56:00 AM  74374327130       743743
# 1             Saturday  2018/12/01 09:18:00 PM  74370071000       743700
# 2               Monday  2019/03/18 02:21:00 PM  78164004134       781640
# 3            Wednesday  2019/03/20 02:06:00 PM  78169706244       781697
# 4              Tuesday  2019/03/15 06:02:00 PM  78154706372       781547
#
#    Incident Number   CAD Number  ...   Longitude  \
# 0        180908554  183360210.0  ... -122.404795
# ...

# %%
p2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194356 entries, 0 to 194355
# Data columns (total 34 columns):
# Incident Datetime                                       194356 non-null object
# Incident Date                                           194356 non-null object
# Incident Time                                           194356 non-null object
# Incident Year                                           194356 non-null int64
# Incident Day of Week                                    194356 non-null object
# Report Datetime                                         194356 non-null object
# Row ID                                                  194356 non-null int64
# Incident ID                                             194356 non-null int64
# Incident Number                                         194356 non-null int64
# CAD Number                                              149783 non-null float64
# ...

# %%
# show all column names
p2.columns
# Out:
# Index(['Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Report Datetime', 'Row ID', 'Incident ID',
#        'Incident Number', 'CAD Number', 'Report Type Code',
#        'Report Type Description', 'Filed Online', 'Incident Code',
#        'Incident Category', 'Incident Subcategory', 'Incident Description',
#        'Resolution', 'Intersection', 'CNN', 'Police District',
#        'Analysis Neighborhood', 'Supervisor District', 'Latitude', 'Longitude',
#        'point', 'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'HSOC Zones as of 2018-06-05', 'OWED Public Spaces',
#        'Central Market/Tenderloin Boundary Polygon - Updated',
#        'Parks Alliance CPSI (27+TL sites)'],
#       dtype='object')

# %%
p2.shape
# Out:
# (194356, 34)

# %%
p2.isnull().sum()
# Out:
# Incident Datetime                                            0
# Incident Date                                                0
# Incident Time                                                0
# Incident Year                                                0
# Incident Day of Week                                         0
# Report Datetime                                              0
# Row ID                                                       0
# Incident ID                                                  0
# Incident Number                                              0
# CAD Number                                               44573
# Report Type Code                                             0
# Report Type Description                                      0
# Filed Online                                            152667
# Incident Code                                                0
# Incident Category                                           17
# ...

# %%
# remove irrelavant columns
p2.drop(['Incident Datetime', 'Incident Year', 'Report Datetime', 'Filed Online', 'Row ID', 'Incident ID', 
         'CAD Number', 'Report Type Code', 'Report Type Description', 'Incident Code', 'CNN', 
         'HSOC Zones as of 2018-06-05', 'OWED Public Spaces', 'Incident Subcategory',
        'Central Market/Tenderloin Boundary Polygon - Updated', 'Supervisor District','Analysis Neighborhood',
        'Parks Alliance CPSI (27+TL sites)'], axis=1, inplace=True)
p2.head()
# Out:
#   Incident Date Incident Time Incident Day of Week  Incident Number  \
# 0    2018/12/02         00:45               Sunday        180908554
# 1    2018/12/01         20:30             Saturday        180908112
# 2    2019/03/18         14:01               Monday        190194129
# 3    2019/03/20         08:00            Wednesday        190199583
# 4    2019/03/12         13:30              Tuesday        196055103
#
#      Incident Category               Incident Description  \
# 0  Other Miscellaneous      Burglary Tools, Possession Of
# 1        Lost Property                      Lost Property
# 2              Assault                            Battery
# 3        Larceny Theft  Theft, From Locked Vehicle, >$950
# 4        Larceny Theft    Theft, Other Property, $50-$200
#
#              Resolution                 Intersection Police District  \
# 0  Cite or Arrest Adult          04TH ST \ JESSIE ST        Southern
# ...

# %%
p2.shape
# Out:
# (194356, 16)

# %%
# change column names to be consistent with p1
p2.columns = ['Date', 'Time', 'DayOfWeek', 'IncidntNum', 'Category', 'Descript', 'Resolution',
              'Address', 'PdDistrict', 'Y', 'X', 'Location', 'SF Find Neighborhoods', 
              'Current Police Districts',  'Current Supervisor Districts', 'Analysis Neighborhoods']
p2.head()
# Out:
#          Date   Time  DayOfWeek  IncidntNum             Category  \
# 0  2018/12/02  00:45     Sunday   180908554  Other Miscellaneous
# 1  2018/12/01  20:30   Saturday   180908112        Lost Property
# 2  2019/03/18  14:01     Monday   190194129              Assault
# 3  2019/03/20  08:00  Wednesday   190199583        Larceny Theft
# 4  2019/03/12  13:30    Tuesday   196055103        Larceny Theft
#
#                             Descript            Resolution  \
# 0      Burglary Tools, Possession Of  Cite or Arrest Adult
# 1                      Lost Property        Open or Active
# 2                            Battery  Cite or Arrest Adult
# 3  Theft, From Locked Vehicle, >$950        Open or Active
# 4    Theft, Other Property, $50-$200        Open or Active
#
#                        Address PdDistrict          Y           X  \
# 0          04TH ST \ JESSIE ST   Southern  37.784908 -122.404795
# 1      POWELL ST \ OFARRELL ST    Central  37.786410 -122.408036
# ...

# %%
# convert p2['date'] from string to datetime
p2['Date'] = pd.to_datetime(p2['Date'])
p2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194356 entries, 0 to 194355
# Data columns (total 16 columns):
# Date                            194356 non-null datetime64[ns]
# Time                            194356 non-null object
# DayOfWeek                       194356 non-null object
# IncidntNum                      194356 non-null int64
# Category                        194339 non-null object
# Descript                        194356 non-null object
# Resolution                      194356 non-null object
# Address                         183893 non-null object
# PdDistrict                      194356 non-null object
# Y                               183893 non-null float64
# X                               183893 non-null float64
# Location                        183893 non-null object
# SF Find Neighborhoods           180068 non-null float64
# Current Police Districts        183585 non-null float64
# Current Supervisor Districts    183862 non-null float64
# ...

# %%
p_2018 = p2[p2['Date'].dt.year < 2019]
p_2018.head()
# Out:
#           Date   Time DayOfWeek  IncidntNum             Category  \
# 0   2018-12-02  00:45    Sunday   180908554  Other Miscellaneous
# 1   2018-12-01  20:30  Saturday   180908112        Lost Property
# 52  2018-11-16  01:34    Friday   196076472        Larceny Theft
# 157 2018-08-19  23:00    Sunday   180625134        Larceny Theft
# 216 2018-12-31  01:00    Monday   196076290        Larceny Theft
#
#                               Descript            Resolution  \
# 0        Burglary Tools, Possession Of  Cite or Arrest Adult
# 1                        Lost Property        Open or Active
# 52        Theft, Other Property, >$950        Open or Active
# 157  Theft, From Locked Vehicle, >$950        Open or Active
# 216  Theft, From Locked Vehicle, >$950        Open or Active
#
#                      Address PdDistrict          Y           X  \
# 0        04TH ST \ JESSIE ST   Southern  37.784908 -122.404795
# 1    POWELL ST \ OFARRELL ST    Central  37.786410 -122.408036
# ...

# %% [markdown]
# # 3. Combine the 2 datasets

# %%
# Combine the 2 datasets and reset the indexes
p00 = pd.concat([p2003_2017, p_2018], ignore_index=True)
p00.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                     Address  Analysis Neighborhoods       Category  \
# 0    800 Block of BRYANT ST                    34.0        ASSAULT
# 1     500 Block of JONES ST                    36.0        ASSAULT
# 2     500 Block of JONES ST                    36.0       BURGLARY
# 3     500 Block of JONES ST                    36.0    WEAPON LAWS
# 4  500 Block of VALENCIA ST                    20.0  LARCENY/THEFT
#
#    Current Police Districts  Current Supervisor Districts       Date  \
# 0                       1.0                          10.0 2017-12-31
# 1                       5.0                          10.0 2017-12-31
# ...

# %%
p00.isnull().sum()
# Out:
# Address                          7894
# Analysis Neighborhoods           8991
# Category                           15
# Current Police Districts         9233
# Current Supervisor Districts     8563
# Date                                0
# DayOfWeek                           0
# Descript                            0
# IncidntNum                          0
# Location                         7894
# PdDistrict                          1
# Resolution                          0
# SF Find Neighborhoods           16811
# Time                                0
# X                                7894
# Y                                7894
# dtype: int64

# %%
p00.shape
# Out:
# (2322659, 16)

# %% [markdown]
# # to remove duplicated crime incidents by using 'IncidntNum' and keeping the first row of the duplicated ones and keep the 1st row when there's a duplicate as the category was listed in the order of severity.

# %%
p0 = p00.drop_duplicates('IncidntNum')
p0.head()
# Out:
#                     Address  Analysis Neighborhoods       Category  \
# 0    800 Block of BRYANT ST                    34.0        ASSAULT
# 1     500 Block of JONES ST                    36.0        ASSAULT
# 4  500 Block of VALENCIA ST                    20.0  LARCENY/THEFT
# 5  700 Block of HARRISON ST                    34.0  LARCENY/THEFT
# 6      HEMLOCK ST / POLK ST                    21.0    DRUNKENNESS
#
#    Current Police Districts  Current Supervisor Districts       Date  \
# 0                       1.0                          10.0 2017-12-31
# 1                       5.0                          10.0 2017-12-31
# 4                       3.0                           5.0 2017-12-31
# 5                       1.0                          10.0 2017-12-31
# 6                       4.0                           3.0 2017-12-31
#
#   DayOfWeek                                      Descript  IncidntNum  \
# 0    Sunday                                       BATTERY   180000417
# ...

# %%
p0.shape
# Out:
# (1822068, 16)

# %%
p0.isnull().sum()
# Out:
# Address                          6415
# Analysis Neighborhoods           7276
# Category                            8
# Current Police Districts         7489
# Current Supervisor Districts     6940
# Date                                0
# DayOfWeek                           0
# Descript                            0
# IncidntNum                          0
# Location                         6415
# PdDistrict                          1
# Resolution                          0
# SF Find Neighborhoods           13495
# Time                                0
# X                                6415
# Y                                6415
# dtype: int64

# %% [markdown]
# ## Save the new merged dataset as "p0".

# %%
p0.to_csv('datasets/p0.csv')
